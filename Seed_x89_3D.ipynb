# %%
import numpy as np

# %%
# 加载预处理后的数据X89,其形状为(样本数,8,9,5)
X89 = np.load("./source/DE0.5s/X89.npy")
# img_rows, img_cols, num_chan = 17, 19, 5
# 设置图像的行数、列数和通道数
img_rows, img_cols, num_chan = 8, 9, 5
# falx = X89
# 扩充到17*19
# if img_rows == 17:
#     tmp_z = np.zeros((1, 1, 9, 5))
#     for i in range(9):
#         idx = 8 - i
#         X89 = np.insert(X89, idx, values=tmp_z, axis=1)
#     tmp_x = np.zeros((45*3394, 17, 19, 5))
#     for i in range(9):
#         tmp_x[:, :, i*2+1, :] = X89[:, :, i, :]
#     falx = tmp_x

# falx = falx.reshape((45, 6788, img_rows, img_cols, 5))

# 初始化存储最终样本的列表
falx11 = []
falx22 = []
falx33 = []

# 划分数据,每个被试有3次实验,共15个被试,因此是3*15=45
for i in range(45):
    # 取当前被试对应的样本     
    if i % 3 == 0:
        curfalx = X89[int(i / 3) * 20246 : int(i / 3) * 20246 + 6870]
        falx11.append(curfalx)
    elif i % 3 == 1:
        curfalx = X89[int(i / 3) * 20246 + 6870 : int(i / 3) * 20246 + 13598]
        falx22.append(curfalx)
    elif i % 3 == 2:
        curfalx = X89[int(i / 3) * 20246 + 13598 : int(i / 3) * 20246 + 20246]
        falx33.append(curfalx)
    
# 将分组后的数据转换为numpy数组
falx1 = np.array(falx11)
falx2 = np.array(falx22)
falx3 = np.array(falx33)


    

# t = 6
# if t == 2:   ns = 3394  # 10182
# elif t == 3: ns = 2257  # 6771
# elif t == 4: ns = 1692  # 5076
# elif t == 5: ns = 1354  # 4062
# elif t == 6: ns = 1126  # 3378
# elif t == 7: ns = 962   # 2886
# elif t == 8: ns = 842   # 2526
# elif t == 9: ns = 746   # 2238
# elif t == 10: ns = 675  # 2025
# elif t == 11: ns = 611  # 1833
# elif t == 12: ns = 559  # 1677

# 设置segment为3秒,每个trial为0.5秒,因此t = 3/0.5 = 6
t = 6
# 根据序列长度设置每个被试样本的数量
if t == 6:   # 6870    6728    6648
    ns1 = 1145
    ns2 = 1121
    ns3 = 1101

# 初始化存储最终样本和标签的数组
new_x = np.zeros((45, ns3, t, img_rows, img_cols, 5))
new_y = np.array([])
# label = [ 1,  0, -1, -1,  0,  1, -1,  0,  1,  1,  0, -1,  0,  1, -1]
# [235, 233, 206, 238, 185,  195,  237,  216,  265,  237,  235,  233,  235,  238,  206]
# [235, 468, 674, 912, 1097, 1292, 1529, 1745, 2010, 2247, 2482, 2715, 2950, 3188, 3394]

# [470, 466, 412,  476,  370,  390,  474,  432,  530,  474,  470,  466,  470,  476,  412]
# [470, 936, 1348, 1824, 2194, 2584, 3058, 3490, 4020, 4494, 4964, 5430, 5900, 6376, 6788]

# 对每个被试的每次实验进行特征处理
for nb in range(45):
    print(nb)
    
    #sample_index初始化
    z = 0
    i = 0
    # 将6648划分为24部分（非均等分），即对应25个影片的情绪。例如0~336，就是1的标签
    #  # 根据被试的样本组分别处理
    if nb % 3 == 0:
        falx = falx1
        while i+t <= 336:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 336
        while i+t <= 526:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 526
        while i+t <= 924:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 924
        while i+t <= 1184:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 1184
        while i+t <= 1360:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 1360
        while i+t <= 1684:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 1684
        while i+t <= 1990:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 1990
        while i+t <= 2408:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 2408
        while i+t <= 2698:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 2698
        while i+t <= 3036:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 3036
        while i+t <= 3136:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 3136
        while i+t <= 3356:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 3356
        while i+t <= 3790:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 3790
        while i+t <= 4128:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 4128
        while i+t <= 4646:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4646
        while i+t <= 4928:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4928
        while i+t <= 5064:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5064
        while i+t <= 5422:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5422
        while i+t <= 5702:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5702
        while i+t <= 5798:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5798
        while i+t <= 6022:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6022
        while i+t <= 6246:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6246
        while i+t <= 6596:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6596
        while i+t <= 6648+12:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        print('{}-{}'.format(nb, z))
        print(new_y.shape)

    elif nb % 3 == 1:
        falx = falx2
        while i+t <= 442:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 442
        while i+t <= 644:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 644
        while i+t <= 922:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 922
        while i+t <= 1214:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 1214
        while i+t <= 1642:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 1642
        while i+t <= 1864:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 1864
        while i+t <= 2142:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 2142
        while i+t <= 2510:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 2510
        while i+t <= 2786:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 2786
        while i+t <= 2952:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 2952
        while i+t <= 3432:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 3432
        while i+t <= 3532:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 3532
        while i+t <= 3824:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 3824
        while i+t <= 4040:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 4040
        while i+t <= 4392:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4392
        while i+t <= 4514:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4514
        while i+t <= 4888:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4888
        while i+t <= 5280:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5280
        while i+t <= 5644:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5644
        while i+t <= 5730:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5730
        while i+t <= 6028:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6028
        while i+t <= 6380:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6380
        while i+t <= 6576:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6576
        while i+t <= 6648+18:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        print('{}-{}'.format(nb, z))
        print(new_y.shape)
        
    elif nb % 3 == 2:
        falx = falx3
        while i+t <= 340:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 340
        while i+t <= 600:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 600
        while i+t <= 784:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 784
        while i+t <= 1148:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 1148
        while i+t <= 1534:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 1534
        while i+t <= 1746:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 1746
        while i+t <= 2262:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 2262
        while i+t <= 2448:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 2448
        while i+t <= 2656:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 2656
        while i+t <= 2784:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 2784
        while i+t <= 3198:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 3198
        while i+t <= 3528:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 3528
        while i+t <= 3842:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 0)
            i = i + t
            z = z + 1
        i = 3842
        while i+t <= 3996:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, 1)
            i = i + t
            z = z + 1
        i = 3996
        while i+t <= 4226:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4226
        while i+t <= 4580:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4580
        while i+t <= 4694:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4694

        while i+t <= 4834:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 4834
        while i+t <= 5200:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5200
        while i+t <= 5378:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5378
        while i+t <= 5696:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 5696
        while i+t <= 6006:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6006
        while i+t <= 6336:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        i = 6336
        while i+t <= 6648:
            new_x[nb, z] = falx[int(nb/3), i:i + t]
            new_y = np.append(new_y, -1)
            i = i + t
            z = z + 1
        print('{}-{}'.format(nb, z))
        print(new_y.shape)

# 保存最终样本和标签
np.save('./source/DE0.5s/t'+str(t)+'x_89.npy', new_x)
np.save('./source/DE0.5s/t'+str(t)+'y_89.npy', new_y)
# np.save('./source/DE0.5s/t'+str(t)+'y_89_1.npy', new_y)
# Out:
# 0
# 0-1101
# (1101,)
# 1
# 1-1101
# (2202,)
# 2
# 2-1101
# (3303,)
# 3
# 3-1101
# (4404,)
# 4
# 4-1101
# (5505,)
# 5
# 5-1101
# (6606,)
# 6
# 6-1101
# (7707,)
# 7
# 7-1101
# (8808,)
# 8
# 8-1101
# (9909,)
# 9
# 9-1101
# (11010,)
# 10
# 10-1101
# (12111,)
# 11
# 11-1101
# (13212,)
# 12
# 12-1101
# (14313,)
# 13
# 13-1101
# (15414,)
# 14
# 14-1101
# (16515,)
# 15
# 15-1101
# (17616,)
# 16
# 16-1101
# (18717,)
# 17
# 17-1101
# (19818,)
# 18
# 18-1101
# (20919,)
# 19
# 19-1101
# (22020,)
# 20
# 20-1101
# (23121,)
# 21
# 21-1101
# (24222,)
# 22
# 22-1101
# (25323,)
# 23
# 23-1101
# (26424,)
# 24
# 24-1101
# (27525,)
# 25
# 25-1101
# (28626,)
# 26
# 26-1101
# (29727,)
# 27
# 27-1101
# (30828,)
# 28
# 28-1101
# (31929,)
# 29
# 29-1101
# (33030,)
# 30
# 30-1101
# (34131,)
# 31
# 31-1101
# (35232,)
# 32
# 32-1101
# (36333,)
# 33
# 33-1101
# (37434,)
# 34
# 34-1101
# (38535,)
# 35
# 35-1101
# (39636,)
# 36
# 36-1101
# (40737,)
# 37
# 37-1101
# (41838,)
# 38
# 38-1101
# (42939,)
# 39
# 39-1101
# ...

# %%
new_x.shape
# Out:
# (45, 1108, 6, 8, 9, 5)

# %%
X89 = np.load("./source/DE0.5s/X89.npy")
y = np.load("./source/DE0.5s/y.npy")
X_new = np.load("./source/DE0.5s/t6x_89.npy")
y_new = np.load("./source/DE0.5s/t6y_89.npy")

# %%
print(X89.shape)
print(y.shape)
print(X_new.shape)
print(y_new.shape)
# Out:
# (305460, 8, 9, 5)
# (305460,)
# (45, 1126, 6, 8, 9, 5)
# (50670,)

# %%
falx = X89.reshape((45, 6788, 8, 9, 5))
falx.shape
# Out:
# (45, 6788, 8, 9, 5)

# %%
X89 = np.load("./source/DE0.5s/X89.npy")
print(X89.shape)
print(type(X89))
# Out:
# (303690, 8, 9, 5)
# <class 'numpy.ndarray'>

# %%
tempfalx = []
for i in range(3):
    if i % 3 == 0:
        curfalx = X89[int(i / 3) * 20246 : int(i / 3) * 20246 + 6870]
    elif i % 3 == 1:
        curfalx = X89[int(i / 3) * 20246 + 6870 : int(i / 3) * 20246 + 13598]
    elif i % 3 == 2:
        curfalx = X89[int(i / 3) * 20246 + 13598 : int(i / 3) * 20246 + 20246]
    print(curfalx.shape)
    tempfalx.append(curfalx)
# Out:
# (6870, 8, 9, 5)
# (6728, 8, 9, 5)
# (6648, 8, 9, 5)

# %%
falx1.shape
# Out:
# (15, 6870, 8, 9, 5)

# %%
new_x.shape
# Out:
# (45, 1108, 6, 8, 9, 5)

# %%
print(2/3)
# Out:
# 0.6666666666666666
